# %%
import pandas as pd
import numpy as np

DATASET_PATH = '../risultati/codeonly_transformed_data_gcp.csv'
df = pd.read_csv(DATASET_PATH)

# %%
df = df.fillna(-1)
df['k'] = df['k'].astype(int)

# %%
df
# Out:
#     Unnamed: 0                      test   k            pass@k       pass@k.1  \
# 0         -1.0                        -1  -1     Compile check  Compile check
# 1         -1.0                        -1  -1  Llama-2-codeonly    Llama-2-mix
# 2         54.0  cloudfunctions2_function   1             100.0          100.0
# 3         55.0  cloudfunctions2_function   5             100.0          100.0
# 4         56.0  cloudfunctions2_function  10             100.0          100.0
# 5         57.0          compute_firewall   1              95.0           95.0
# 6         58.0          compute_firewall   5             100.0          100.0
# 7         59.0          compute_firewall  10             100.0          100.0
# 8         60.0          compute_instance   1              85.0           85.0
# 9         61.0          compute_instance   5             100.0          100.0
# 10        62.0          compute_instance  10             100.0          100.0
# ...
