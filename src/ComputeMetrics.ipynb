# %%
import pandas as pd

DATASET_PATH = '../risultati/mix-t06.csv'
df = pd.read_csv(DATASET_PATH)

# %%
df
# Out:
#                         test          provider                 scores  none  \
# 0           apigatewayv2_api               aws   11001211010111101021     6
# 1             dynamodb_table               aws   00000000000000000000    20
# 2                   iam_role               aws   22222222202222222202     2
# 3                   instance               aws   22200202220022000002    10
# 4                     lambda               aws   02020111112022102122     5
# 5                lambda_hard               aws   42002002022202000022    10
# 6                         lb               aws   11111111111111111111     0
# 7                    lb_hard               aws   33311111123331112000     3
# 8               aws_provider               aws  022202222000020222202     8
# 9                  s3_bucket               aws             0000000002     9
# 10                       vpc               aws   22222222220222222222     1
# 11         function_app_hard           azurerm   01000000000000000000    19
# 12      provider_block_azure           azurerm   00022021111111200000     9
# 13            resource_group           azurerm   11111111200020200000     9
# 14            security_group           azurerm   00000022220102122122     8
# 15           storage_account           azurerm   00022002020202000200    13
# 16                    subnet           azurerm   02000000000000020200    17
# 17           virtual_network           azurerm   02222202202211112121     3
# 18  cloudfunctions2_function            google   22111111111111111211     0
# 19          compute_firewall            google   22111212222202122222     1
# 20          compute_instance            google   22222020202222222222     3
# 21       compute_subnetworks            google   11111111111111111112     0
# 22         google_prov_block            google   22022022202022222220     5
# 23            storage_bucket            google   22212222202220020222     4
# 24    storage_bucket_website            google   00000000000100000000    19
# 25             few_variables  terraform_basics   11111111111111111111     0
# 26                one_output  terraform_basics   22212222122122121222     0
# 27              one_variable  terraform_basics   01110101101111111101     5
# 28       output_and_variable  terraform_basics   22222222112212122222     0
#
#     c_compile  c_functional  c_almost  c_functional_subset   n  \
# 0          12             2         0                    0  20
# 1           0             0         0                    0  20
# 2           0            18         0                    0  20
# 3           0            10         0                    0  20
# 4           7             8         0                    0  20
# 5           0             9         0                    1  20
# 6          20             0         0                    0  20
# 7           9             2         6                    0  20
# 8           0            13         0                    0  21
# 9           0             1         0                    0  10
# 10          0            19         0                    0  20
# 11          1             0         0                    0  20
# 12          7             4         0                    0  20
# 13          8             3         0                    0  20
# 14          3             9         0                    0  20
# 15          0             7         0                    0  20
# 16          0             3         0                    0  20
# 17          6            11         0                    0  20
# 18         17             3         0                    0  20
# 19          5            14         0                    0  20
# 20          0            17         0                    0  20
# 21         19             1         0                    0  20
# 22          0            15         0                    0  20
# 23          1            15         0                    0  20
# 24          1             0         0                    0  20
# 25         20             0         0                    0  20
# 26          5            15         0                    0  20
# 27         15             0         0                    0  20
# 28          4            16         0                    0  20
#
#     pass@5_compile  pass@5_func  pass@1_compile  pass@1_func  pass@10_compile  \
# 0         0.999613     0.447368        0.700000     0.100000         1.000000
# 1         0.000000     0.000000        0.000000     0.000000         0.000000
# 2         1.000000     1.000000        0.900000     0.900000         1.000000
# 3         0.983746     0.983746        0.500000     0.500000         0.999995
# 4         0.999936     0.948916        0.750000     0.400000         1.000000
# 5         0.983746     0.983746        0.500000     0.500000         0.999995
# 6         1.000000     0.000000        1.000000     0.000000         1.000000
# 7         1.000000     0.447368        0.850000     0.100000         1.000000
# 8         0.997248     0.997248        0.619048     0.619048         1.000000
# 9         0.500000     0.500000        0.100000     0.100000         1.000000
# 10        1.000000     1.000000        0.950000     0.950000         1.000000
# 11        0.250000     0.000000        0.050000     0.000000         0.500000
# 12        0.991873     0.718266        0.550000     0.200000         1.000000
# 13        0.991873     0.600877        0.550000     0.150000         1.000000
# 14        0.996388     0.970201        0.600000     0.450000         1.000000
# 15        0.916989     0.916989        0.350000     0.350000         0.998452
# 16        0.600877     0.600877        0.150000     0.150000         0.894737
# 17        1.000000     0.991873        0.850000     0.550000         1.000000
# 18        1.000000     0.600877        1.000000     0.150000         1.000000
# 19        1.000000     0.999613        0.950000     0.700000         1.000000
# 20        1.000000     1.000000        0.850000     0.850000         1.000000
# 21        1.000000     0.250000        1.000000     0.050000         1.000000
# 22        0.999936     0.999936        0.750000     0.750000         1.000000
# 23        1.000000     0.999936        0.800000     0.750000         1.000000
# 24        0.250000     0.000000        0.050000     0.000000         0.500000
# 25        1.000000     0.000000        1.000000     0.000000         1.000000
# 26        1.000000     0.999936        1.000000     0.750000         1.000000
# 27        0.999936     0.000000        0.750000     0.000000         1.000000
# 28        1.000000     1.000000        1.000000     0.800000         1.000000
#
#     pass@10_func
# 0       0.763158
# 1       0.000000
# 2       1.000000
# 3       0.999995
# 4       0.999643
# 5       0.999995
# 6       0.000000
# 7       0.763158
# 8       1.000000
# 9       1.000000
# 10      1.000000
# 11      0.000000
# 12      0.956656
# 13      0.894737
# 14      0.999940
# 15      0.998452
# 16      0.894737
# 17      1.000000
# 18      0.894737
# 19      1.000000
# 20      1.000000
# 21      0.500000
# 22      1.000000
# 23      1.000000
# 24      0.000000
# 25      0.000000
# 26      1.000000
# 27      0.000000
# 28      1.000000

# %%
NONE                = 0;    NONE_KEY='none'
COMPILE_SUCCESSES   = 1;    COMPILE_KEY='c_compile'
FUNCTIONAL_SUCCESS  = 2;    FUNCTIONAL_KEY='c_functional'
ALMOST_SUCCESS      = 3;    ALMOST_KEY='c_almost'
SUBSET_SUCCESS      = 4;    SUBSET_KEY='c_functional_subset'
SCORES_KEY = 'scores'
N_KEY = 'n'

# %%
from utils import pass_at_k

COUNT_ALMOST_AS_FUNC = False
COUNT_SUBSET_AS_FUNC = True

compile_match   = [COMPILE_KEY, ALMOST_KEY, SUBSET_KEY, FUNCTIONAL_KEY]
func_match      = [FUNCTIONAL_KEY]

if COUNT_ALMOST_AS_FUNC:    func_match.append(ALMOST_KEY)
if COUNT_SUBSET_AS_FUNC:    func_match.append(SUBSET_KEY)

# %%
from typing import List


def sum_over_columns(x: dict, columns: List[str]) -> int:
    return sum([int(x[key]) for key in columns])

# %%
K = 10
COMPILE_K_KEY = f"pass@{K}_compile"
FUNC_K_KEY = f"pass@{K}_func"


df[COMPILE_K_KEY]   = df.apply(lambda x: pass_at_k(x[N_KEY], sum_over_columns(x, compile_match), K), axis=1)
df[FUNC_K_KEY]      = df.apply(lambda x: pass_at_k(x[N_KEY], sum_over_columns(x, func_match), K), axis=1)

# %%
df
# Out:
#                         test                 scores  none  c_compile  \
# 0           apigatewayv2_api   11001211010111101021     6         12
# 1             dynamodb_table   00000000000000000000    20          0
# 2                   iam_role   22222222202222222202     2          0
# 3                   instance   22200202220022000002    10          0
# 4                     lambda   02020111112022102122     5          7
# 5                lambda_hard   42002002022202000022    10          0
# 6                         lb   11111111111111111111     0         20
# 7                    lb_hard   33311111123331112000     3          9
# 8               aws_provider  022202222000020222202     8          0
# 9                  s3_bucket             0000000002     9          0
# 10                       vpc   22222222220222222222     1          0
# 11         function_app_hard   01000000000000000000    19          1
# 12      provider_block_azure   00022021111111200000     9          7
# 13            resource_group   11111111200020200000     9          8
# 14            security_group   00000022220102122122     8          3
# 15           storage_account   00022002020202000200    13          0
# 16                    subnet   02000000000000020200    17          0
# 17           virtual_network   02222202202211112121     3          6
# 18  cloudfunctions2_function   22111111111111111211     0         17
# 19          compute_firewall   22111212222202122222     1          5
# 20          compute_instance   22222020202222222222     3          0
# 21       compute_subnetworks   11111111111111111112     0         19
# 22         google_prov_block   22022022202022222220     5          0
# 23            storage_bucket   22212222202220020222     4          1
# 24    storage_bucket_website   00000000000100000000    19          1
# 25             few_variables   11111111111111111111     0         20
# 26                one_output   22212222122122121222     0          5
# 27              one_variable   01110101101111111101     5         15
# 28       output_and_variable   22222222112212122222     0          4
#
#     c_functional  c_almost  c_functional_subset   n  pass@5_compile  \
# 0              2         0                    0  20        0.999613
# 1              0         0                    0  20        0.000000
# 2             18         0                    0  20        1.000000
# 3             10         0                    0  20        0.983746
# 4              8         0                    0  20        0.999936
# 5              9         0                    1  20        0.983746
# 6              0         0                    0  20        1.000000
# 7              2         6                    0  20        1.000000
# 8             13         0                    0  21        0.997248
# 9              1         0                    0  10        0.500000
# 10            19         0                    0  20        1.000000
# 11             0         0                    0  20        0.250000
# 12             4         0                    0  20        0.991873
# 13             3         0                    0  20        0.991873
# 14             9         0                    0  20        0.996388
# 15             7         0                    0  20        0.916989
# 16             3         0                    0  20        0.600877
# 17            11         0                    0  20        1.000000
# 18             3         0                    0  20        1.000000
# 19            14         0                    0  20        1.000000
# 20            17         0                    0  20        1.000000
# 21             1         0                    0  20        1.000000
# 22            15         0                    0  20        0.999936
# 23            15         0                    0  20        1.000000
# 24             0         0                    0  20        0.250000
# 25             0         0                    0  20        1.000000
# 26            15         0                    0  20        1.000000
# 27             0         0                    0  20        0.999936
# 28            16         0                    0  20        1.000000
#
#     pass@5_func  pass@1_compile  pass@1_func  pass@10_compile  pass@10_func
# 0      0.447368        0.700000     0.100000         1.000000      0.763158
# 1      0.000000        0.000000     0.000000         0.000000      0.000000
# 2      1.000000        0.900000     0.900000         1.000000      1.000000
# 3      0.983746        0.500000     0.500000         0.999995      0.999995
# 4      0.948916        0.750000     0.400000         1.000000      0.999643
# 5      0.983746        0.500000     0.500000         0.999995      0.999995
# 6      0.000000        1.000000     0.000000         1.000000      0.000000
# 7      0.447368        0.850000     0.100000         1.000000      0.763158
# 8      0.997248        0.619048     0.619048         1.000000      1.000000
# 9      0.500000        0.100000     0.100000         1.000000      1.000000
# 10     1.000000        0.950000     0.950000         1.000000      1.000000
# 11     0.000000        0.050000     0.000000         0.500000      0.000000
# 12     0.718266        0.550000     0.200000         1.000000      0.956656
# 13     0.600877        0.550000     0.150000         1.000000      0.894737
# 14     0.970201        0.600000     0.450000         1.000000      0.999940
# 15     0.916989        0.350000     0.350000         0.998452      0.998452
# 16     0.600877        0.150000     0.150000         0.894737      0.894737
# 17     0.991873        0.850000     0.550000         1.000000      1.000000
# 18     0.600877        1.000000     0.150000         1.000000      0.894737
# 19     0.999613        0.950000     0.700000         1.000000      1.000000
# 20     1.000000        0.850000     0.850000         1.000000      1.000000
# 21     0.250000        1.000000     0.050000         1.000000      0.500000
# 22     0.999936        0.750000     0.750000         1.000000      1.000000
# 23     0.999936        0.800000     0.750000         1.000000      1.000000
# 24     0.000000        0.050000     0.000000         0.500000      0.000000
# 25     0.000000        1.000000     0.000000         1.000000      0.000000
# 26     0.999936        1.000000     0.750000         1.000000      1.000000
# 27     0.000000        0.750000     0.000000         1.000000      0.000000
# 28     1.000000        1.000000     0.800000         1.000000      1.000000

# %%
df.groupby(by='provider').mean(numeric_only=True)
# Out:
#                      n      none  c_compile  c_functional  c_almost  \
# provider
# aws               19.0  3.727273   3.090909      9.090909  2.363636
# azurerm           20.0  4.857143   3.000000     11.857143  0.000000
# google            20.0  3.000000   6.142857     10.571429  0.000000
# terraform_basics  20.0  6.250000  11.000000      2.750000  0.000000
#
#                   c_functional_subset  pass@1_compile  pass@1_func  \
# provider
# aws                          0.727273        0.772727     0.496411
# azurerm                      0.285714        0.757143     0.607143
# google                       0.285714        0.850000     0.542857
# terraform_basics             0.000000        0.687500     0.137500
#
#                   pass@5_compile  pass@5_func  pass@10_compile  pass@10_func
# provider
# aws                     0.863631     0.796487         0.909091      0.896528
# azurerm                 0.845284     0.738141         0.856922      0.785493
# google                  0.857143     0.701266         0.857143      0.714065
# terraform_basics        0.927535     0.247968         0.989164      0.250000

# %%
df.groupby(by='provider').sum(numeric_only=True)
# Out:
#                     n  none  c_compile  c_functional  c_almost  \
# provider
# aws               209    41         34           100        26
# azurerm           140    34         21            83         0
# google            140    21         43            74         0
# terraform_basics   80    25         44            11         0
#
#                   c_functional_subset  pass@1_compile  pass@1_func  \
# provider
# aws                                 8            8.50     5.460526
# azurerm                             2            5.30     4.250000
# google                              2            5.95     3.800000
# terraform_basics                    0            2.75     0.550000
#
#                   pass@5_compile  pass@5_func  pass@10_compile  pass@10_func
# provider
# aws                     9.499936     8.761352        10.000000      9.861812
# azurerm                 5.916989     5.166989         5.998452      5.498452
# google                  6.000000     4.908862         6.000000      4.998452
# terraform_basics        3.710139     0.991873         3.956656      1.000000

# %%
df.to_csv(DATASET_PATH, index=False)
